# %%
import sys
import numpy as np

def rb(x):
    x1=x[0]
    x2=x[1]
    
    return 100*(x2-x1**2)**2+(1-x1)**2

# %%
x=np.linspace(-2,2,51)
y=np.linspace(-1,3,51)
print(x)
z=[]
for j in range(len(y)):
    for i in range(len(x)):
        z.append(rb(np.array([x[i],y[j]])))
z=np.array(z).reshape(len(y),len(x))
print(z)
# Out:
# [-2.   -1.92 -1.84 -1.76 -1.68 -1.6  -1.52 -1.44 -1.36 -1.28 -1.2  -1.12
#  -1.04 -0.96 -0.88 -0.8  -0.72 -0.64 -0.56 -0.48 -0.4  -0.32 -0.24 -0.16
#  -0.08  0.    0.08  0.16  0.24  0.32  0.4   0.48  0.56  0.64  0.72  0.8
#   0.88  0.96  1.04  1.12  1.2   1.28  1.36  1.44  1.52  1.6   1.68  1.76
#   1.84  1.92  2.  ]
# [[2509.       2204.760896 1931.414336 ... 1924.054336 2197.080896
#   2501.      ]
#  [2429.64     2130.418496 1861.884736 ... 1854.524736 2122.738496
#   2421.64    ]
#  [2351.56     2057.356096 1793.635136 ... 1786.275136 2049.676096
#   2343.56    ]
#  ...
#  [ 143.56       80.165696   37.833536 ...   30.473536   72.485696
#    135.56    ]
#  [ 125.64       67.263296   29.743936 ...   22.383936   59.583296
#    117.64    ]
#  [ 109.         55.640896   22.934336 ...   15.574336   47.960896
#    101.      ]]

# %%
from matplotlib import pyplot as plt
from mpl_toolkits.mplot3d import Axes3D

X,Y = np.meshgrid(x,y)

print(X)
print(Y)
# Out:
# [[-2.   -1.92 -1.84 ...  1.84  1.92  2.  ]
#  [-2.   -1.92 -1.84 ...  1.84  1.92  2.  ]
#  [-2.   -1.92 -1.84 ...  1.84  1.92  2.  ]
#  ...
#  [-2.   -1.92 -1.84 ...  1.84  1.92  2.  ]
#  [-2.   -1.92 -1.84 ...  1.84  1.92  2.  ]
#  [-2.   -1.92 -1.84 ...  1.84  1.92  2.  ]]
# [[-1.   -1.   -1.   ... -1.   -1.   -1.  ]
#  [-0.92 -0.92 -0.92 ... -0.92 -0.92 -0.92]
#  [-0.84 -0.84 -0.84 ... -0.84 -0.84 -0.84]
#  ...
#  [ 2.84  2.84  2.84 ...  2.84  2.84  2.84]
#  [ 2.92  2.92  2.92 ...  2.92  2.92  2.92]
#  [ 3.    3.    3.   ...  3.    3.    3.  ]]

# %%
fig = plt.figure()
ax = Axes3D(fig)
surf = ax.plot_surface(X,Y,z)
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
from matplotlib import pyplot as plt
import numpy as np
f = np.loadtxt('f.txt')
t = np.arange(len(f))
plt.plot(t,f)
plt.show()
xa = np.loadtxt('xa.txt')
print(xa.shape)
plt.scatter(xa[:,0],xa[:,1])
plt.show()
# Out:
# (62, 2)
